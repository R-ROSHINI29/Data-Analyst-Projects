# %%
#Pandas
#Import Pandas, Numpy in pycharm
import pandas as pd

# **** I had taken a order dataset so i stored the datasets into order ****

order = pd.read_excel(r"C:\Users\USER\Downloads\mccDhWL5Sya3oeJlgOB5Hw_2d90bb67af8a4bc68ca789b7071d82e1_data.xlsx")
print(order.head(5)) #head means print first elements, Tail means print last elements
print(order['Cost']) #when we want particular columns
print(order[['Order ID','Revenue','Cost']]) #Multi col
print(order.loc[order['Revenue'].isnull()]) #to view only null data's

###*FILTERING DATA'S
order = pd.read_excel(r"C:\Users\USER\Downloads\mccDhWL5Sya3oeJlgOB5Hw_2d90bb67af8a4bc68ca789b7071d82e1_data.xlsx", index_col = "Order ID")
print(order.head(5))
#order_filtering = order.(order['Cost']>1000)
#print(order_filtering.head(5))


#order_filtering = order[order['Cost'] > 1000]

#print(order_filtering.head(5))
order_filtering = order[order['Rush Shipment'] == 'Yes']
print(order_filtering.head(5))

#AGGREGATE FUNCTIONS
print(order.mean)
print(order.head(5))

print(order["Cost"].mean())
print(order["Cost"].max())
print(order["Cost"].min())
print(order["Cost"].sum())

#Data Cleaning
#Removing unwanted columns
order_cleaning = order.drop(["Rush Shipment"], axis = 1)
print(order_cleaning.head(5))

#Remove null values by using dropna it removes only null value col
order_cleaning = order_cleaning.dropna (subset = ['Revenue'], axis = 0)
print(order_cleaning.head(5))

#if we want to replace null value then we can use (fillna)
#order_cleaning = order_cleaning.fillna (["Revenue"] : 0)
##standardization chars lower, upper..etc

order = pd.read_excel(r"C:\Users\USER\Downloads\mccDhWL5Sya3oeJlgOB5Hw_2d90bb67af8a4bc68ca789b7071d82e1_data.xlsx")
print(order.head(5))
order ["Rush Shipment"] = order ["Rush Shipment"].str.upper()
print(order.head(5))

#Remove duplicated
order = order.drop_duplicates()

import numpy as np
array = [1,2,3,4]
print(array)
print(type(array))
math = array * 2
print(math)
